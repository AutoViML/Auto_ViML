# %% [markdown]
# # The UCI Bikeshare data set (Multi Label Regression) is an Excellent Example of how to use Auto_ViML to teach people what works and what doesnt in ML for each data set (which can be different! hence the name Variant in Viml):
# Steps to do:
#     1.  Try Basic Linear Model (Lasso) with HyperParameter Tuning. Look at the Results.
#     2.  Compare that to the Ensembling model and see if that improves results
#     3.  Since there seems to be a Poly shape in Residuals, add_poly variables next. See if that improves.
#     4.  Finally bring in the Bazooka: Add Stacking Flag to True and see how that makes the Model improve.
#     5.  It is nice to see how experimenting with Multiple Techniques in Auto_ViML makes it so easy to Tune and Learn!

# %% [markdown]
# ### Thanks to UCI Machine Learning Repository
# Citation Request:
#
# Fanaee-T, Hadi, and Gama, Joao, 'Event labeling combining ensemble detectors and background knowledge', Progress in Artificial Intelligence (2013): pp. 1-15, Springer Berlin Heidelberg, [Web Link].
# Dataset Found here: https://archive.ics.uci.edu/ml/datasets/bike+sharing+dataset

# %%
import sys
print(sys.version)
sys.path.append('../Auto_ViML/')
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
pd.options.display.max_columns=1000
datapath = '../data_sets/'
# Out:
# 3.7.1 (default, Dec 14 2018, 19:28:38)
# [GCC 7.3.0]

# %%
target = ['casual','registered']
idcol = ''
sep=','
modeltype = 'Regression'
excl = ['cnt', 'temp']

# %%
df = pd.read_csv(datapath+'bikeshare.csv',sep=sep,
                 header=0,
                 index_col=None)
df.drop(excl,axis=1,inplace=True)
print(df.shape)
df.head()
# Out:
# (17379, 15)
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit   atemp   hum  windspeed  casual  registered
# 0           1  0.2879  0.81        0.0       3          13
# 1           1  0.2727  0.80        0.0       8          32
# 2           1  0.2727  0.80        0.0       5          27
# 3           1  0.2879  0.75        0.0       3          10
# 4           1  0.2879  0.75        0.0       0           1

# %%
num = int(0.9*df.shape[0])
train = df[:num]
test = df[num:]
sample_submission=''
scoring_parameter = ''

# %%
col = 'dteday'
#train = train.set_index(col)

# %%
namevars = ['atemp','hum','windspeed']

# %%
from Auto_ViML import Auto_ViML
#### If Boosting_Flag = True => XGBoost, False=>ExtraTrees, None=>Linear Model
model, features, trainm, testm = Auto_ViML(train, target, test,sample_submission='',hyper_param='GS',
            scoring_parameter='mae', Boosting_Flag=None, KMeans_Featurizer=False,
            Add_Poly=0, Stacking_Flag=False, Binning_Flag=False,
              Imbalanced_Flag=False, verbose=2)
# Out:
# Train (Size: 15641,15) has Multi_Label with target: ['casual', 'registered']
# "
#  ################### Regression  ######################
# "
#  ################### Regression  ######################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  5
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  3
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     13 Predictors classified...
#         This does not include the Target column(s)
#     1 variables removed since they were some ID or low-information variables
# Test data has no missing values...
# Number of numeric variables = 3
# ...

# %%
def accu(results, y_cv):
    return (results==y_cv).astype(int).sum(axis=0)/(y_cv.shape[0])
def rmse(results, y_cv):
    return np.sqrt(np.mean((results - y_cv)**2, axis=0))

# %%
#accu(m.predict(testm[feats]),pd.factorize(test[target].values)[0])

# %%
from Auto_ViML import print_regression_model_stats
ech = target[0]
lab1 = pd.read_csv(ech+'/'+ech+'_Regression_submission.csv',index_col=None)
print_regression_model_stats(test[ech].values,lab1[ech+'_Bagging1_predictions'].values)
lab1.head(1)
# Out:
#     MAE = 18.0946
#     MAPE = inf%
#     RMSE = 25.9490
#     MAE as % std dev of Actuals = 40.6%
#     Normalized RMSE (% of MinMax of Actuals) = 7%
#     Normalized RMSE (% of Std Dev of Actuals) = 58%
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0    15642  2012-10-18       4   1    10  22        0        4           1
#
#    weathersit   atemp   hum  windspeed  casual  registered  \
# 0           2  0.5152  0.83      0.194      27         202
#
#    casual_Bagging1_predictions  casual_LassoCV Regularization_predictions  \
# 0                        24.05                                    38.3745
#
#    casual_RidgeCV Regression_predictions  casual_Boosting_predictions  \
# 0                              38.248497                     67.14473
#
#    casual_Linear_predictions  casual_Ensembled_predictions
# 0                  49.369335                     43.437412

# %%
ech = target[1]
lab1 = pd.read_csv(ech+'/'+ech+'_Regression_submission.csv',index_col=None)
print_regression_model_stats(test[ech].values,lab1[ech+'_Bagging1_predictions'].values)
lab1.head(1)
# Out:
#     MAE = 66.6817
#     MAPE = inf%
#     RMSE = 109.3668
#     MAE as % std dev of Actuals = 40.5%
#     Normalized RMSE (% of MinMax of Actuals) = 12%
#     Normalized RMSE (% of Std Dev of Actuals) = 66%
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0    15642  2012-10-18       4   1    10  22        0        4           1
#
#    weathersit   atemp   hum  windspeed  casual  registered  \
# 0           2  0.5152  0.83      0.194      27         NaN
#
#    casual_Bagging1_predictions  casual_LassoCV Regularization_predictions  \
# 0                        24.05                                    38.3745
#
#    casual_RidgeCV Regression_predictions  casual_Boosting_predictions  \
# 0                              38.248497                     67.14473
#
#    casual_Linear_predictions  casual_Ensembled_predictions  \
# 0                  49.369335                     43.437412
#
#    registered_Bagging1_predictions  \
# ...
